# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a=np.random.random(100)
b=a*2+(np.random.randn(100)-0.5)*0.1
plt.scatter(a, b)

# %%
p=0
lr=0.01

# %%
for i in range(100):
    cost=0
    for j in range(100):
        costt=a[j]*p-b[j]
        cost+=costt
        p -= costt*a[j]*lr
    print(cost/100)
# Out:
# -0.79309519458266
# -0.5646725667117907
# -0.4007397958066335
# -0.283089659184289
# -0.19865532326212967
# -0.1380590733359566
# -0.0945707760098504
# -0.06336039572017871
# -0.04096154596707117
# -0.024886494474401003
# -0.013349862757134345
# -0.005070332738799519
# 0.0008716630711137445
# 0.005136073505865582
# 0.008196526077319613
# 0.010392930500728476
# 0.0119692308283882
# 0.013100499139678453
# 0.013912379953044814
# 0.014495044957035302
# 0.014913207945106855
# 0.015213312264733712
# 0.015428689056146678
# 0.015583259181418807
# 0.01569418999931179
# 0.01577380206106597
# 0.01583093749463693
# 0.015871942057229634
# 0.015901369927962986
# 0.01592248951859261
# 0.015937646480249604
# 0.01594852422360689
# 0.01595633088718638
# 0.015961933519482722
# 0.015965954377859207
# 0.015968840039675025
# 0.015970911001478974
# 0.01597239727501481
# 0.01597346393352168
# 0.01597422944561721
# 0.01597477883304068
# 0.015975173113605447
# 0.015975456078152747
# 0.015975659154190844
# ...

# %%
plt.scatter(a, b)
plt.plot([0, 1], [0, p])

# %%
p
# Out:
# 1.8770773366650222
