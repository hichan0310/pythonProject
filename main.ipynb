# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a=np.random.random(100)
b=a*2+(np.random.randn(100)-0.5)*0.1
plt.scatter(a, b)

# %%
p=0
lr=0.01

# %%
for i in range(100):
    cost=0
    for j in range(100):
        costt=b[j]-a[j]*p
        cost+=costt
        p -= -costt*a[j]*lr
    print(cost/100)
# Out:
# 0.7230700223545496
# 0.527371130033489
# 0.3829770178149941
# 0.2764375305645408
# 0.1978286304563848
# 0.13982798360056217
# 0.09703289257314189
# 0.06545704100380222
# 0.04215917252421085
# 0.024969115923507906
# 0.012285636050908448
# 0.0029272804959851635
# -0.003977671423524312
# -0.009072408498955657
# -0.012831499969880812
# -0.015605101134683774
# -0.017651569937291372
# -0.019161532729776793
# -0.020275640910553498
# -0.021097672449775007
# -0.021704198694833084
# -0.02215171690841915
# -0.022481912927343473
# -0.02272554415307682
# -0.022905304570375026
# -0.023037938667379475
# -0.023135801166546673
# -0.023208007853662744
# -0.02326128470341242
# -0.023300594396636152
# -0.023329598588674668
# -0.023350998988597178
# -0.023366789020473587
# -0.023378439508668487
# -0.02338703568353639
# -0.023393378269453792
# -0.023398058071427995
# -0.023401511007944232
# -0.023404058716298023
# -0.023405938512762788
# -0.02340732549834268
# -0.023408348869242465
# ...

# %%
plt.scatter(a, b)
plt.plot([0, 1], [0, p])

# %%
p
# Out:
# 1.8262540153268747
